# %%
import numpy as np
import pandas as pd

# %%
path = r'C:\Users\hp\Desktop\M2\PFE\Code\code pfe\dataset\6.xlsx'
df=pd.read_excel(path)

# %%
df.columns
# Out:
# Index(['index', 'CHKP (kPa)', 'SPM1 (1/s)', 'SKNO', 'SPM2 (1/s)', 'SPM3 (1/s)',
#        'SQID', 'TVA (m3)', 'DATE', 'TIME', 'MFOP ((m3/s)/(m3/s))', 'ACTC',
#        'MFOA (m3/s)', 'DBTM (m)', 'DBTV (m)', 'MFIA (m3/s)', 'DMEA (m)',
#        'MDIA (kg/m3)', 'DVER (m)', 'MTOA (degC)', 'BPOS (m)', 'MTIA (degC)',
#        'ROPA (m/h)', 'MCOA (S/m)', 'HKLA (N)', 'MCIA (S/m)', 'HKLX (N)',
#        'STKC', 'WOBA (N)', 'WOBX (N)', 'DRTM (m)', 'TQA (N.m)', 'TQX (N.m)',
#        'GASA (mol/mol)', 'RPMA (rad/s)', 'SPPA (kPa)', 'RIG_STATE',
#        'MDOA (kg/m3)', 'ROPI (m/s)', 'Unnamed: 39', 'STATUS', 'Unnamed: 41'],
#       dtype='object')

# %%
merged_data = pd.DataFrame()
path = r'C:\Users\hp\Desktop\M2\PFE\Code\code pfe\dataset'
files = ['6.xlsx',
         '8.xlsx',
         '15.xlsx',
         '17.xlsx',
         '19.xlsx',
         '26.xlsx',
         '29.xlsx']
cols=['index','CHKP (kPa)','TVA (m3)','MTIA (degC)','DBTM (m)', 'DMEA (m)','SPPA (kPa)',
       'MFOP ((m3/s)/(m3/s))', 'MDIA (kg/m3)','GASA (mol/mol)','STATUS','id']
for i in files:
    df=pd.read_excel(path+'\\'+i)
    df['id']=i
    print(i)
    x=max(df[df['STATUS']==1].index)
    merged_data = merged_data.append(df[cols][:x+1], ignore_index=True)
# Out:
# 6.xlsx
# C:\Users\hp\AppData\Local\Temp\ipykernel_7396\4129663722.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(df[cols][:x+1], ignore_index=True)
# 8.xlsx
# C:\Users\hp\AppData\Local\Temp\ipykernel_7396\4129663722.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(df[cols][:x+1], ignore_index=True)
# 15.xlsx
# C:\Users\hp\AppData\Local\Temp\ipykernel_7396\4129663722.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   merged_data = merged_data.append(df[cols][:x+1], ignore_index=True)
# 17.xlsx
# ...

# %%
merged_data['id'].unique
# Out:
# <bound method Series.unique of 0         6.xlsx
# 1         6.xlsx
# 2         6.xlsx
# 3         6.xlsx
# 4         6.xlsx
#           ...
# 53245    29.xlsx
# 53246    29.xlsx
# 53247    29.xlsx
# 53248    29.xlsx
# 53249    29.xlsx
# Name: id, Length: 53250, dtype: object>

# %%
cols=['CHKP (kPa)','TVA (m3)','MTIA (degC)','DBTM (m)', 'DMEA (m)','SPPA (kPa)',
       'MFOP ((m3/s)/(m3/s))', 'MDIA (kg/m3)','GASA (mol/mol)','STATUS']

# %%
data=merged_data[merged_data['STATUS']==1]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
cols1=['CHKP (kPa)','TVA (m3)','MTIA (degC)','DBTM (m)', 'DMEA (m)','SPPA (kPa)',
       'MFOP ((m3/s)/(m3/s))', 'MDIA (kg/m3)','GASA (mol/mol)']
correlation_matrix = data[cols1].corr()
# Create the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='crest', square=True)

# Set the title
plt.title('Correlation Matrix Heatmap')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
merged_data[['CHKP (kPa)','TVA (m3)','MTIA (degC)','DBTM (m)', 'DMEA (m)','SPPA (kPa)',
       'MFOP ((m3/s)/(m3/s))', 'MDIA (kg/m3)','GASA (mol/mol)','STATUS']].plot(subplots=True,figsize=(20,25))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
merged_data[cols]= scaler.fit_transform(merged_data[cols])

# %%
import matplotlib.pyplot as plt
merged_data[['CHKP (kPa)','TVA (m3)','MTIA (degC)','DBTM (m)', 'DMEA (m)','SPPA (kPa)',
       'MFOP ((m3/s)/(m3/s))', 'MDIA (kg/m3)','GASA (mol/mol)','STATUS']].plot(subplots=True,figsize=(20,25))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
merged_data.to_excel('data_kick_.xlsx',index=False)

# %%
df=pd.read_excel(r'C:\Users\hp\Desktop\M2\PFE\Code\code pfe\dataset\all_data.xlsx')
df.shape
# Out:
# (110737, 7)

# %%
print(max(df[df['STATUS']==1].index))
# Out:
# 106256

# %%
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12652\1002051947.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['index'] = pd.to_datetime(df['index'],format='%d/%m/%Y, %H:%M:%S')

# %%
data=data.rename(columns={'index': 'time'})

# %%
cols=['TVA (m3)', 'SPPA (kPa)',
       'MFOP ((m3/s)/(m3/s))', 'GASA (mol/mol)']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17280 entries, 0 to 17279
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   time                  17280 non-null  datetime64[ns]
#  1   TVA (m3)              17280 non-null  float64
#  2   SPPA (kPa)            17280 non-null  float64
#  3   MFOP ((m3/s)/(m3/s))  17280 non-null  float64
#  4   GASA (mol/mol)        17280 non-null  float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 675.1 KB

# %%
import pandas as pd
from tsfresh import extract_features
from tsfresh.utilities.dataframe_functions import impute
from tsfresh.feature_extraction import ComprehensiveFCParameters


# Add a constant 'id' column for the single well
data['id'] = 1

# Convert your data to long format
long_data = data.melt(id_vars=["id", "time"], var_name="attribute", value_name="value")

long_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69120 entries, 0 to 69119
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         69120 non-null  int64
#  1   time       69120 non-null  datetime64[ns]
#  2   attribute  69120 non-null  object
#  3   value      69120 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 2.1+ MB

# %%
# Extract features using tsfresh
extraction_settings = ComprehensiveFCParameters()
extracted_features = extract_features(long_data, column_id="id", column_sort="time", column_kind="attribute", column_value="value", default_fc_parameters=extraction_settings)

# Impute missing values in the extracted features
imputed_features = impute(extracted_features)

# Merge the extracted features with the original dataset
final_data = data.merge(imputed_features, on="id")
# Out:
# Feature Extraction:   0%|          | 0/4 [06:54<?, ?it/s]
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\multiprocessing\pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\tsfresh\utilities\distribution.py", line 43, in _function_with_partly_reduce
#     results = list(itertools.chain.from_iterable(results))
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\tsfresh\utilities\distribution.py", line 42, in <genexpr>
#     results = (map_function(chunk, **kwargs) for chunk in chunk_list)
# ...

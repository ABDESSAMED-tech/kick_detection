# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
df=pd.read_excel(r'C:\Users\hp\Desktop\M2\PFE\Code\code pfe\Coud source\Code\data\Well-6_01-07-2022.xlsx')

# %%
df.head()
# Out:
#                   index  TVA (m3)  SPPA (kPa)  MFOA (m3/s)  \
# 0  07/01/2022, 00:00:01      39.2   82.737088            0
# 1  07/01/2022, 00:00:06      39.2   68.947573            0
# 2  07/01/2022, 00:00:11      39.2   68.947573            0
# 3  07/01/2022, 00:00:16      39.1   68.947573            0
# 4  07/01/2022, 00:00:21      39.2   68.947573            0
#
#    MFOP ((m3/s)/(m3/s))  GASA (mol/mol)  STATUS Unnamed: 41
# 0                  0.05             0.0       0         NaN
# 1                  0.05             0.0       0         NaN
# 2                  0.05             0.0       0         NaN
# 3                  0.05             0.0       0         NaN
# 4                  0.05             0.0       0         NaN

# %%
cols=['TVA (m3)', 'SPPA (kPa)', 'MFOA (m3/s)',
       'MFOP ((m3/s)/(m3/s))', 'GASA (mol/mol)',]

# %%
ctd=df['STATUS']>=1

# %%
ctd.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: STATUS, dtype: bool

# %%
result = df.loc[ctd, cols]

# print the result
result.head(100)
# Out:
#     TVA (m3)  SPPA (kPa)  MFOA (m3/s)  MFOP ((m3/s)/(m3/s))  GASA (mol/mol)
# 0       39.2   82.737088            0                  0.05             0.0
# 1       39.2   68.947573            0                  0.05             0.0
# 2       39.2   68.947573            0                  0.05             0.0
# 3       39.1   68.947573            0                  0.05             0.0
# 4       39.2   68.947573            0                  0.05             0.0
# ..       ...         ...          ...                   ...             ...
# 95      39.1   41.368544            0                  0.05             0.0
# 96      39.2   34.473786            0                  0.05             0.0
# 97      39.2   27.579029            0                  0.05             0.0
# 98      39.2   41.368544            0                  0.05             0.0
# 99      39.2   27.579029            0                  0.05             0.0
#
# [100 rows x 5 columns]

# %%
df['MFOA (m3/s)'].head()
# Out:
# 0    0.000215
# 1    0.000215
# 2    0.000213
# 3    0.000213
# 4    0.000212
# Name: MFOA (m3/s), dtype: float64

# %%
df_=df[cols].astype(float)

# %%
df_training.plot.line()
# Out:
# <Axes: >

# %%
# create a MinMaxScaler object to normalize the data between 0 and 1
min_max_scaler = MinMaxScaler()

# create a StandardScaler object to standardize the data
standard_scaler = StandardScaler()

# assuming your data is in a pandas DataFrame called 'df'
# normalize the data between 0 and 1 using MinMaxScaler
df_normalized_minmax = pd.DataFrame(min_max_scaler.fit_transform(df_p), columns=df_p.columns)

# standardize the data using StandardScaler
df_normalized_standard = pd.DataFrame(standard_scaler.fit_transform(df_p), columns=df_p.columns)

# %%
df_normalized_minmax.plot.line()
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#           TVA (m3)   SPPA (kPa)  MFOA (m3/s)  MFOP ((m3/s)/(m3/s))  \
# count  6399.000000  6399.000000  6399.000000           6399.000000
# mean     76.305461  1932.578947     0.000126              0.075486
# std       3.755719  1456.304332     0.000050              0.029971
# min      61.778713     9.150900     0.000030              0.017705
# 25%      73.831474   896.070400     0.000098              0.058735
# 50%      75.595764  1378.252100     0.000098              0.058993
# 75%      78.198726  3091.423750     0.000200              0.119748
# max      89.467331  4388.185900     0.000241              0.144538
#
#        GASA (mol/mol)       STATUS
# count     6399.000000  6399.000000
# mean         0.016536     0.013440
# std          0.027150     0.115157
# min          0.000602     0.000000
# 25%          0.001017     0.000000
# 50%          0.003987     0.000000
# 75%          0.014027     0.000000
# max          0.141960     1.000000

# %%
for i in range()
# Out:
# 0       0.000602
# 1       0.000616
# 2       0.000602
# 3       0.000602
# 4       0.000606
#           ...
# 6394    0.001040
# 6395    0.001039
# 6396    0.001040
# 6397    0.001040
# 6398    0.001039
# Name: GASA (mol/mol), Length: 6399, dtype: float64
